# %%
import pandas as pd
import json
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
classfile_in = 'hubbles-hot-stars-classifications.csv'
classifications = pd.read_csv(classfile_in)
len(classifications)
# Out:
# /Users/bkayitesi/miniconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 116210

# %%
subjectsfile_in = 'hubbles-hot-stars-classifications.csv'
subjects = pd.read_csv(subjectsfile_in)
workflowsfile_in= 'hubbles-hot-stars-classifications.csv'
workflows = pd.read_csv(workflowsfile_in)
# Out:
# /Users/bkayitesi/miniconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
classifications['metadata_json'] = [json.loads(q) for q in classifications.metadata]
classifications['annotations_json'] =[json.loads(q) for q in classifications.annotations]
classifications['subject_data_json'] = [json.loads(q) for q in classifications.subject_data]

# %%
ngc7793 = classifications[classifications.workflow_name == 'NGC 7793']
ngc1313 = classifications[classifications.workflow_name == 'NGC 1313']
ngc4395 = classifications[classifications.workflow_name == 'NGC 4395']
len(ngc1313)

ngc7793['ngc7793yn'] =([q[0]['value'] for q in ngc7793.annotations_json])
ngc7793['id']= (q[0] for q in ngc7793.subject_data_json)
#print (ngc7793['ngc7793yn'])
ngc7793.subject_data
# Out:
# /Users/bkayitesi/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/bkayitesi/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 17163    {"3950499":{"retired":null,"rgbimage":"subimg7...
# 17218    {"3948599":{"retired":null,"rgbimage":"subimg7...
# 18128    {"3948325":{"retired":null,"rgbimage":"subimg7...
# 18141    {"3950216":{"retired":null,"rgbimage":"subimg7...
# ...
